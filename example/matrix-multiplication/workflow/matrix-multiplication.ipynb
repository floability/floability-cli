# %%
def multiply_pair(A, B):
    import numpy as np  # Only on the worker
    A_np = np.array(A, dtype=float)
    B_np = np.array(B, dtype=float)
    C_np = A_np @ B_np
    return C_np.tolist()  # convert back to nested list

# %%
import os

manager_name = api_key = os.environ.get("VINE_MANAGER_NAME")
print(f"Manager name: {manager_name}")

ports_str = os.environ.get("VINE_MANAGER_PORTS", "9123, 9150")
ports = [int(p.strip()) for p in ports_str.split(",")]
print(f"Ports: {ports}")
# Out:
# Manager name: floability-7e535e1d-5343-45f5-8dd4-8f7259a77797
# Ports: [9123, 9150]

# %%
import random
import ndcctools.taskvine as vine

N = 50      # 50x50 matrices
num_pairs = 10  # We'll do 10 pairs for demonstration

A_list = []
B_list = []

for _ in range(num_pairs):
    A_mat = [[random.random() for _ in range(N)] for _ in range(N)]
    B_mat = [[random.random() for _ in range(N)] for _ in range(N)]
    A_list.append(A_mat)
    B_list.append(B_mat)

m = vine.Manager(ports, name=manager_name)

print(f"[manager] Listening on port {m.port}")

tasks_map = {}
results = [None]*num_pairs
failed_tasks = []

for i in range(num_pairs):
    task = vine.PythonTask(multiply_pair, A_list[i], B_list[i])
    t_id = m.submit(task)
    tasks_map[t_id] = i
    print(f"[manager] Submitted multiplication for pair index {i}.")

print("[manager] Waiting for tasks to complete...")
while not m.empty():
    done_task = m.wait(5)
    if done_task:
        idx = tasks_map[done_task.id]
        if done_task.successful():
            C = done_task.output
            results[idx] = C
            print(f"[manager] Pair {idx} -> result row0 length = {len(C[0])}, Computed On: {done_task.addrport}")
        else:
            failed_tasks.append(idx)
            print(
                f"[manager] Task for pair {idx} failed: "
                f"result={done_task.result}, exit_code={done_task.exit_code}"
            )
            if done_task.std_output:
                print(done_task.std_output)

if failed_tasks:
    raise RuntimeError(
        f"{len(failed_tasks)} TaskVine task(s) failed: {failed_tasks}"
    )

print("\n[manager] All tasks completed successfully.")
# Out:
# [manager] Listening on port 9123
# [manager] Submitted multiplication for pair index 0.
# [manager] Submitted multiplication for pair index 1.
# [manager] Submitted multiplication for pair index 2.
# [manager] Submitted multiplication for pair index 3.
# [manager] Submitted multiplication for pair index 4.
# [manager] Submitted multiplication for pair index 5.
# [manager] Submitted multiplication for pair index 6.
# [manager] Submitted multiplication for pair index 7.
# [manager] Submitted multiplication for pair index 8.
# [manager] Submitted multiplication for pair index 9.
# [manager] Waiting for tasks to complete...
# [manager] Pair 0 -> result row0 length = 50, Computed On: 172.17.0.2:46316
# [manager] Pair 1 -> result row0 length = 50, Computed On: 172.17.0.2:46330
# [manager] Pair 2 -> result row0 length = 50, Computed On: 172.17.0.2:46316
# [manager] Pair 3 -> result row0 length = 50, Computed On: 172.17.0.2:46330
# [manager] Pair 4 -> result row0 length = 50, Computed On: 172.17.0.2:46316
# [manager] Pair 5 -> result row0 length = 50, Computed On: 172.17.0.2:46330
# [manager] Pair 6 -> result row0 length = 50, Computed On: 172.17.0.2:46316
# [manager] Pair 7 -> result row0 length = 50, Computed On: 172.17.0.2:46330
# [manager] Pair 8 -> result row0 length = 50, Computed On: 172.17.0.2:46316
# [manager] Pair 9 -> result row0 length = 50, Computed On: 172.17.0.2:46330
#
# [manager] All tasks completed successfully.

# %%
from datetime import datetime

print(f"Workflow completed at: {datetime.now().astimezone().isoformat()}")
# Out:
# Workflow completed at: 2026-08-16T20:10:02.293899+00:00
